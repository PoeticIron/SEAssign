# %% [markdown]
# # Word Embeddings
# This document contains the source code for the addition of word embeddings.

# %% [markdown]
# ## Step 1: Get embeddings & setup for desired embedding.

# %%
##Harvest the embeddings from files.
filew2 = "w2_vectors.txt"
filew5 = "w5_vectors.txt"
filew7 = "w7_vectors.txt"
#skip-gram embeddings files:
filew2sg = "w2_vectors_sg.txt"
filew5sg = "w5_vectors_sg.txt"
filew7sg = "w7_vectors_sg.txt"


##To modify which embeddings are used:
##change the dictFile to 'candidateDictw[WINDOW SIZE]' with suffix 'SG' for skip-gram
##change the outFile to 'EmbeddedOutput[WINDOW SIZE]' with suffix 'SG' for skip-gram
##change the input to the below 'with open(FILENAME)' to one of the files above.

dictFile = "candidateDictw2SG.txt"
##change this to prevent over-writing the wrong file for output!
outFile = open("EmbeddedOutput2SG.txt","w")
with open(filew2sg, "rb") as f:
    wText = f.read().decode('utf-8')
Words = wText.split("\n")
Words.pop(0)
# Out:
# '93951 300'

# %% [markdown]
# ##  Vectorize function:
# From the text provided by the embeddings file, convert into a set of word:vector relationships as a Dict for accessibility.

# %%
def vectorize(vectors):
    i = 0
    print("Vectorizing " + str(vectors.__len__()-1) + " words")
    output = {}
    for iWord in vectors:
        i += 1
        split = iWord.split(" ")
        thisWord = split[0]
        split.pop(0)
        if(thisWord != "" ):
            split.pop()
            list = []
            for f in split:
                list.append(float(f))
            output[thisWord] = list
        if (i % 10000 == 0):
            print("Vectorizing word:" + str(i))
    return output
wVec = vectorize(Words)
# Out:
# Vectorizing 93951 words
# Vectorizing word:10000
# Vectorizing word:20000
# Vectorizing word:30000
# Vectorizing word:40000
# Vectorizing word:50000
# Vectorizing word:60000
# Vectorizing word:70000
# Vectorizing word:80000
# Vectorizing word:90000

# %% [markdown]
# ## Getting Queries
# Same as the code used for Task 2 - Generating queries - we open the Topics files and convert these into lists of terms per query.

# %%
##Get the queries to expand on - same code as in Query Processing file.
##read the three query files
filename1 = "topics.51-100.txt"
filename2 = "topics.101-150.txt"
filename3 = "topics.151-200.txt"

with open(filename1, "rb") as f:
    content1 = f.read().decode('utf-8')
with open(filename2, "rb") as f:
    content2 = f.read().decode('utf-8')
with open(filename3, "rb") as f:
    content3 = f.read().decode('utf-8')

##grab individual queries
import re

filteredQ1 = []
filteredQ2 = []
filteredQ3 = []

##break each query block into separate queries.
q1 = content1.split("<title>")
q2 = content2.split("<title>")
q3 = content3.split("<title>")
q1.pop(0)
q2.pop(0)
q3.pop(0)

##For each list of queries:
##Grab only the Topic bracket, and remove the 'Topic:' section
##Replace dashes and slashes with spaces to separate conjoined terms
##Strip all non-alpha/space characters
##Strip double-spacing
##Remove starting whitespace
##append to filtered lists.
for q in q1:
    text = q.split("<desc>")[0].replace("Topic:","")
    text =text.replace("/", " ")
    text =text.replace("-", " ")
    text =text.replace("\n", " ")
    text =text.replace(".", " ")
    text = re.sub("[^a-zA-Z ]","", text)
    text = re.sub(" +"," ", text)
    text = text.lstrip()
    filteredQ1.append(text)
for q in q2:
    text = q.split("<desc>")[0].replace("Topic:","")
    text =text.replace("/", " ")
    text =text.replace("-", " ")
    text =text.replace("\n", " ")
    text =text.replace(".", " ")
    text = re.sub("[^a-zA-Z ]","", text)
    text = re.sub(" +"," ", text)
    text = text.lstrip()
    filteredQ2.append(text)
for q in q3:
    text = q.split("<desc>")[0].replace("Topic:","")
    text =text.replace("/", " ")
    text =text.replace("-", " ")
    text =text.replace("\n", " ")
    text =text.replace(".", " ")
    text = re.sub("[^a-zA-Z ]","", text)
    text = re.sub(" +"," ", text)
    text = text.lstrip()
    filteredQ3.append(text)

# %% [markdown]
# ## Candidate Dictionary Processing & Use
# This is how we store & retrieve our candidate lists from the saved file.
# To start, we open the file and get all the stored candidates from it.
# Later, we'll check against what we've read and if we can't find a new term, it will be added using addCandidate.
# This ensures we only need to find candidates once per unique term.

# %%
##candidate dictionary processing
candidateDictionary = {}

with open(dictFile, "rb") as f:
    dictContent = f.read().decode('utf-8')
dictTerms = dictContent.split("\r\n")
for term in dictTerms:
    thisDict = term.split("~")
    word = thisDict[0]
    terms = thisDict[1].split(" ")
    candidateDictionary[word] = terms
    
print("Dictionary Size: " +str(candidateDictionary.__len__()))

def addCandidate(word,candidates):
    with open(dictFile, "a") as f:
        f.write("\n"+word+"~")
        for term in candidates:
            print(term)
            f.write(term+" ")
# Out:
# Dictionary Size: 478

# %% [markdown]
# ## Query Expansion
# #### Candidate Generation:
# For the first section here, we process each query, looking at each word individually.
# We first check our candidate Dictionary to make sure we don't re-do any terms we've already checked.
# If we can find the word in there, we add its stored candidates to the list of potential terms - the QueryTermsCandidates.
#
# If we can't find the word in there, we compare all terms in the vectors provided from word embeddings with this word's vector.
# This allows us to find the most similar vector in the entire collection - we'll store the highest k (five) terms associated with this one in the dictionary for later, and add these terms to the Candidate collection.
#
# #### Query Expansion:
# Once we're finished creating the candidate set, we parse through these candidates and find the ones that best match all the query terms. This is done by comparing the sum of vector comparisons with the query terms and this candidate, and selecting the best j (three) terms from these.
# These new terms are added to the expandedQueries set to be output later.

# %%
from scipy import spatial
import operator

##combine our queries, and prepare the output set.
combinedQueries = filteredQ1 + filteredQ2 + filteredQ3
expandedQueries = []
##k and j are the two constants for expansion. k= number of candidates to produce per word,
##j = number of final best candidates from all terms to expand query with.
k=5
j=3


def expandQ(vectors,start):
    for query in combinedQueries[0:150]:
        ##Candidate Generation Begins Here:
        start+=1
        queryTerms = query.split(" ")
        ##define the list of candidate terms we'll be using:
        queryTermsCandidates = []
        ##for all words in each query:
        for word in queryTerms:
            candidateWordsOnly = []
            word = word.lower()
            ##check if we've already processed this word.
            if (word in candidateDictionary):
                candidateWordsOnly += candidateDictionary[word]
                for word in candidateWordsOnly:
                    queryTermsCandidates.append(word)
            ##if we haven't processed it, we need to find candidates:
            elif (str(word) in vectors.keys()) & (word != "") :
                ##get the vector for this word
                wordVector = vectors[word]
                vectorComparisons = {}
                ##loop through all words in our embeddings collection. add the word + score to the VectorComparisons dict.
                for vect in vectors.items():
                    vectScore = (1 - spatial.distance.cosine(vect[1], wordVector))##compareVectors(vect,wordVector)
                    vectorComparisons[vect[0]]=vectScore
                    ##vectorComparisons = vectScore
                ##sort our scored comparisons, in the right order.
                sortedComparisons = sorted(vectorComparisons.items(), key=operator.itemgetter(1))
                sortedComparisons.reverse()
                ##only grab the last k.
                candidateDictionary[word] = sortedComparisons[0:k]
                ##for each of the candidate terms, add the terms to both the dictionary, the saved file, and the list of candidates.
                for term in sortedComparisons[0:k]:
                    candidateWordsOnly.append(term[0])
                    queryTermsCandidates.append(term[0])
                addCandidate(word,candidateWordsOnly)
        ##Query Expansion Begins Here:
        ##setup our list of similarity scores per candidate:
        termQscores = []
        ##remove blank entries from list
        candidateTerms = list(filter(lambda a: a != '', queryTermsCandidates))
        ##for each of our candidate terms,
        
        for term in candidateTerms:
            ##Only consider words that aren't in the query (self-translation is OK, but we don't want to expand with duplicates!)
            if term not in (word.lower() for word in queryTerms):
                termScore = 0
                if '' in queryTerms:
                    queryTerms.remove('')
                ##Compare this term with all the words in the query, and sum the scores.
                for word in queryTerms:
                    word=word.lower()
                    if word in vectors:
                        termScore += (1 - spatial.distance.cosine(vectors[term.lower()], vectors[word]))
                termQscores.append((term,termScore))
        ##sort the candidates by their combined similarity:
        termQscores = sorted(termQscores, key=lambda tup: tup[1])
        termQscores.reverse()
        
        
        ##Add the j best candidate terms to the query.
        for t in termQscores[0:j]:
            queryTerms.append(t)
        expandedQueries.append(queryTerms)
            

    
##run the expansion - '51' starting number is for debugging!
expandQ(wVec,51)

# %%
##query output to text file
qNo = 51
##output individual queries to text file
for qu in expandedQueries:
    outFile.write("<top>\n")
    outFile.write("<num>" + str(qNo) + "</num><title>\n")
    for word in qu:
        if isinstance(word, tuple):
            outFile.write(word[0] + " ")
        else:
            outFile.write(word + " ")
    outFile.write("\n</title>\n")
    outFile.write("</top>\n")
    qNo = qNo+1
outFile.close()
# Out:
# 150
# ['Airbus', 'Subsidies', ('industrie', 1.0435378713215067), ('subsidy', 0.905325539985559), ('aircraft', 0.8691413045539917)]
# ['South', 'African', 'Sanctions', ('africa', 1.5865439608153737), ('embargoes', 1.383595974375249), ('disinvestment', 1.3258873086935345)]
# ['Leveraged', 'Buyouts', ('buyout', 1.3675134911333136), ('restructurings', 1.3271809923368283), ('lbo', 1.3124796045044602)]
# ['Satellite', 'Launch', 'Contracts', ('tdrs', 1.4979813220714395), ('geostationary', 1.4708854069879176), ('navstar', 1.4490359552755456)]
# ['Insider', 'Trading', ('frauds', 0.9705184820700984), ('directionless', 0.942517960646976), ('merc', 0.9342479422430824)]
# ['Prime', 'Lending', 'Rate', 'Moves', 'Predictions', ('interst', 2.0784737063822765), ('iniatives', 2.0193693504352552), ('underemployment', 2.0020665229907086)]
# ['MCI', ('sprint', 0.6006605633561322), ('tci', 0.5691070243876946), ('mccaw', 0.5507547828965591)]
# ['Rail', 'Strikes', ('walkouts', 1.062361830274991), ('strike', 1.0534123178735837), ('stoppages', 0.9751259490532894)]
# ['Weather', 'Related', 'Fatalities', ('casualities', 1.3083969089789007), ('fatality', 1.2330817231762343), ('deaths', 1.1805814194238362)]
# ['Merit', 'Pay', 'vs', 'Seniority', ('tomich', 1.5300144217786937), ('duplicative', 1.5150948885792996), ('apportioning', 1.5142427361277626)]
# ['Israeli', 'Role', 'in', 'Iran', 'Contra', 'Affair', ('reinvigoration', 2.5968148642996622), ('imbroglio', 2.5084801058621413), ('irangate', 2.4883705117217834)]
# ['Military', 'Coups', 'Detat', ('insurrections', 1.0893468174731273), ('juntas', 1.0645134160346084), ('militry', 1.0218364928953614)]
# ['Machine', 'Translation', ('fluency', 0.8652517079386008), ('subtitles', 0.8095193517227716), ('silencer', 0.7832620172986942)]
# ['Hostage', 'Taking', ('hostages', 0.9386767551115953), ('took', 0.8818719054890829), ('take', 0.8617604826549924)]
# ['Information', 'Retrieval', 'Systems', ('profs', 1.5362699905315798), ('publicizes', 1.5270094274785602), ('calibrate', 1.5027352713299584)]
# ['Natural', 'Language', 'Processing', ('integrates', 1.140944018911946), ('desalinization', 1.119378162749894), ('fluency', 1.1179446005825844)]
# ['Politically', 'Motivated', 'Civil', 'Disturbances', ('perpetration', 1.6063022891567924), ('insinuation', 1.5879896853432873), ('fazed', 1.4921509787151204)]
# ['Health', 'Hazards', 'from', 'Fine', 'Diameter', 'Fibers', ('jasons', 2.3642224419666538), ('dioxins', 2.3491249445239486), ('endocrinology', 2.284298272437353)]
# ['Attempts', 'to', 'Revive', 'the', 'SALT', 'II', 'Treaty', ('ncfc', 2.9800811783655874), ('minox', 2.9323440465032697), ('mutikori', 2.918714097193032)]
# ['Surrogate', 'Motherhood', ('pronouns', 0.9410370272847846), ('procreation', 0.9311010174374993), ('unwed', 0.9168382816087758)]
# ['Border', 'Incursions', ('infiltrations', 1.1364408766774061), ('incursion', 1.114840563640445), ('shellings', 1.0915648607226458)]
# ['Demographic', 'Shifts', 'in', 'the', 'U', 'S', ('mutikori', 2.89021934176252), ('mutikori', 2.89021934176252), ('besuzzo', 2.8894137852922137)]
# ['Demographic', 'Shifts', 'across', 'National', 'Boundaries', ('realignments', 2.009067106343511), ('postulates', 2.0021187552085715), ('nationa', 1.9508187902042833)]
# ['Conflicting', 'Policy', ('policies', 0.9650051780196784), ('equivocal', 0.897738174767181), ('differing', 0.8846148938792823)]
# ['Automation', ('networked', 0.6033655282381306), ('telecommunication', 0.5880368557058167), ('automating', 0.5870478850976227)]
# ['U', 'S', 'Constitution', 'Original', 'Intent', ('unfpa', 2.1504050841777964), ('besuzzo', 2.0603647728409005), ('annnounced', 2.0477296458830976)]
# ['Poaching', ('poachers', 0.5874815634565703), ('waterfowl', 0.5458816330530448), ('coyotes', 0.5415087564686117)]
# ['Greenpeace', ('vallette', 0.5359223607619906), ('mv', 0.5206502275862455), ('bricklemyer', 0.5178437948889572)]
# ['FRG', 'Political', 'Party', 'Positions', ('democractic', 1.448466559904527), ('politicial', 1.343261709427048), ('politial', 1.3211965399417438)]
# ['Presidential', 'Candidates', 'Platforms', ('presidental', 1.475878745211166), ('slates', 1.4218319666852155), ('candidate', 1.418720496869236)]
# ['Financial', 'crunch', 'for', 'televangelists', 'in', 'the', 'wake', 'of', 'the', 'PTL', 'scandal', ('ncfc', 5.28214144361394), ('ncfc', 5.28214144361394), ('minox', 5.238239226229636)]
# ['Genetic', 'Engineering', ('subcontracted', 0.8900679366036968), ('dna', 0.8885571791832686), ('mutation', 0.8829609818032218)]
# ['Measures', 'to', 'Protect', 'the', 'Atmosphere', ('flexibly', 2.311354776430365), ('minox', 2.269112478201022), ('mutikori', 2.2522300944255695)]
# ['Alternative', 'renewable', 'Energy', 'Plant', 'Equipment', 'Installation', ('renewables', 2.6843754279610206), ('rechlh', 2.651597735336054), ('geothermal', 2.618588010478668)]
# ['Official', 'Corruption', ('cronyism', 0.9930550208227614), ('semiofficial', 0.9653319631065832), ('offical', 0.9636009093061313)]
# ['Bank', 'Failures', ('insolvencies', 0.9518684566423675), ('banks', 0.8815525606930568), ('overbuilding', 0.8588956634821315)]
# ['Criminal', 'Actions', 'Against', 'Officers', 'of', 'Failed', 'Financial', 'Institutions', ('finanical', 3.2051909645632493), ('prosecutes', 3.1856891851636258), ('demotions', 3.152771797847663)]
# ['Crude', 'Oil', 'Price', 'Trends', ('wti', 1.8655175218863889), ('distillates', 1.8649511373777936), ('intemediate', 1.8570198509422011)]
# ['Downstream', 'Investments', 'by', 'OPEC', 'Member', 'States', ('interlinked', 2.5479879889754162), ('sates', 2.3566808989550716), ('nomm', 2.279749110424099)]
# ['Data', 'on', 'Proven', 'Reserves', 'of', 'Oil', 'Natural', 'Gas', 'Producers', ('stablize', 3.814543113049206), ('ocs', 3.77958316353917), ('recoverable', 3.5211145037702227)]
# ['U', 'S', 'Army', 'Acquisition', 'of', 'Advanced', 'Weapons', 'Systems', ('besuzzo', 3.455882798667553), ('unfpa', 3.3394453006456812), ('asat', 3.2342210274797214)]
# ['International', 'Military', 'Equipment', 'Sales', ('militry', 1.6378982165669702), ('miliary', 1.6309153022977383), ('internationl', 1.6152339362542008)]
# ['What', 'Backing', 'Does', 'the', 'National', 'Rifle', 'Association', 'Have', ('mutikori', 3.6177943621266015), ('ncfc', 3.6103515015246694), ('minox', 3.4866543230135862)]
# ['Computer', 'aided', 'Crime', ('abetted', 1.2096083625584733), ('computers', 1.1414944435299996), ('microprocessors', 1.1168063392397145)]
# ['Computer', 'aided', 'Crime', 'Detection', ('tna', 1.5252038238346084), ('abetted', 1.5179932026302576), ('antidotes', 1.5141767244458442)]
# ['Computer', 'Aided', 'Medical', 'Diagnosis', ('electroshock', 1.564130409013226), ('diagnoses', 1.5626863413741747), ('abetted', 1.4896040307038647)]
# ['Fiber', 'Optics', 'Applications', ('adaptive', 1.7205313154986874), ('composites', 1.678554500413897), ('optic', 1.5948579164931675)]
# ['Fiber', 'Optics', 'Equipment', 'Manufacturers', ('adaptive', 2.27493900589636), ('composites', 2.2488353662705927), ('miniaturized', 2.1953266937798457)]
# ['Iran', 'Contra', 'Affair', ('contras', 1.4388637542075355), ('irangate', 1.3962122198437803), ('profumo', 1.384898001470086)]
# ['Controlling', 'the', 'Transfer', 'of', 'High', 'Technology', ('ncfc', 2.653138764446354), ('mutikori', 2.6276681742331007), ('offfice', 2.5576874537223357)]
# ['Design', 'of', 'the', 'Star', 'Wars', 'Anti', 'missile', 'Defense', 'System', ('antimissile', 3.862306646137066), ('ncfc', 3.778962873776737), ('mutikori', 3.638621874068747)]
# ['Laser', 'Research', 'Applicable', 'to', 'the', 'U', 'S', 's', 'Strategic', 'Defense', 'Initiative', ('unfpa', 5.091275467858658), ('ncfc', 4.912823162879782), ('besuzzo', 4.904868699471318)]
# ['Welfare', 'Reform', ('reforms', 0.9929059819696541), ('wic', 0.8779829416942497), ('afdc', 0.8647710185500003)]
# ['Catastrophic', 'Health', 'Insurance', ('uncompensated', 1.6258478878264275), ('uncompensated', 1.6258478878264275), ('medicare', 1.417976515468757)]
# ['Black', 'Monday', ('tuesday', 1.1298314369531062), ('friday', 1.1204424048626724), ('wednesday', 1.1086900395944874)]
# ['U', 'S', 'Control', 'of', 'Insider', 'Trading', ('besuzzo', 2.5612222762433405), ('unfpa', 2.4544271970811344), ('offfice', 2.4418192516200583)]
# ['Japanese', 'Regulation', 'of', 'Insider', 'Trading', ('agaisnt', 2.0704852484793324), ('japanse', 2.0608757107541047), ('offfice', 1.9811505581717368)]
# ['Japanese', 'Protectionist', 'Measures', ('japanse', 1.3815393474936963), ('stategy', 1.2988416371919862), ('agaisnt', 1.295189658153348)]
# ['Find', 'Innovative', 'Companies', ('generalize', 1.4162665577911686), ('printmaking', 1.408851284516256), ('firms', 1.2436313844045437)]
# ['Black', 'Resistance', 'Against', 'the', 'South', 'African', 'Government', ('mutikori', 3.2055844483110585), ('governmment', 3.056852312368317), ('ncfc', 3.002723994521735)]
# ['Nuclear', 'Proliferation', ('snf', 1.0466583540067576), ('thermonuclear', 1.0295441322165542), ('constrains', 1.02306536026768)]
# ['Funding', 'Biotechnology', ('commercialize', 0.9696468355143074), ('microgravity', 0.957667791172735), ('consortia', 0.9559997176836507)]
# ['New', 'Space', 'Satellite', 'Applications', ('spacelab', 1.8599817008591433), ('geostationary', 1.7794252549375003), ('navstar', 1.7056110500888868)]
# ['Non', 'commercial', 'Satellite', 'Launches', ('marcopolo', 1.8251206152019939), ('launchings', 1.7818691011300651), ('geostationary', 1.7698740702689855)]
# ['Impact', 'of', 'the', 'Immigration', 'Law', ('ncfc', 2.2697416149199343), ('mutikori', 2.2169320994476074), ('allots', 2.182740640544032)]
# ['Generic', 'Drug', 'Substitutions', ('brandname', 1.6724494009740916), ('dyazide', 1.6422111612454893), ('descramblers', 1.6080466206381674)]
# ['Capacity', 'of', 'the', 'U', 'S', 'Cellular', 'Telephone', 'Network', ('ncfc', 3.66595410312694), ('besuzzo', 3.5562075643303075), ('telelphone', 3.4796149472965157)]
# ['International', 'Terrorists', ('internationl', 0.9069067841457535), ('interntional', 0.8321758432602863), ('internatinal', 0.8172227456273217)]
# ['Actions', 'Against', 'International', 'Terrorists', ('internationl', 1.610137732323146), ('aginst', 1.5692953776265024), ('agaisnt', 1.566685965257971)]
# ['Economic', 'Impact', 'of', 'International', 'Terrorism', ('ecnomic', 2.103196041057182), ('internationl', 2.0897573837329495), ('interntional', 2.085081729710837)]
# ['Death', 'from', 'Cancer', ('malignancy', 1.2706314767841085), ('lorea', 1.1845785801975208), ('boharski', 1.1683570674056236)]
# ['RDTE', 'of', 'New', 'Cancer', 'Fighting', 'Drugs', ('offfice', 2.0156805980694967), ('ofthe', 1.9732526008772087), ('midamerica', 1.7648127434830356)]
# ['Research', 'into', 'Control', 'of', 'Carcinogens', ('offfice', 2.076388406318691), ('furrows', 2.039827592579196), ('antidotes', 2.0396287256365495)]
# ['Alternatives', 'to', 'Traditional', 'Cancer', 'Therapies', ('flexibly', 2.211109347079335), ('antiviral', 2.1925938171370762), ('streptokinase', 2.1703819773383644)]
# ['Anti', 'smoking', 'Actions', 'by', 'Government', ('governmment', 2.160528827186337), ('nomm', 2.0881921066769076), ('interlinked', 2.086916143151557)]
# ['Medical', 'Ethics', 'and', 'Modern', 'Technology', ('walstad', 2.17127626042429), ('credentialing', 2.15294140351625), ('minjung', 1.9924434694910849)]
# ['U', 'S', 'U', 'S', 'S', 'R', 'Arms', 'Control', 'Agreements', ('unfpa', 4.084490115962192), ('unfpa', 4.084490115962192), ('besuzzo', 3.967124987894338)]
# ['Privatization', 'of', 'State', 'Assets', ('privatizing', 1.7623721659982867), ('emasculation', 1.717678671167938), ('offfice', 1.6437938198804831)]
# ['Soviet', 'Spying', 'on', 'the', 'U', 'S', ('besuzzo', 2.8349508156192558), ('konarski', 2.8086461792165958), ('ncfc', 2.801403182165784)]
# ['Jewish', 'Emigration', 'and', 'U', 'S', 'USSR', 'Relations', ('besuzzo', 3.1812792723866257), ('unfpa', 3.106534086635736), ('bonden', 3.0849761489889205)]
# ['McDonnell', 'Douglas', 'Contracts', 'for', 'Military', 'Aircraft', ('twinjets', 2.852418341827766), ('etak', 2.5896685335287355), ('dcs', 2.5823104834139743)]
# ['Stealth', 'Aircraft', ('bomber', 1.197983726470834), ('planes', 1.1808445795503868), ('plane', 1.0952102341588708)]
# ['Hubble', 'Space', 'Telescope', ('pegsat', 1.6813012708091213), ('spacelab', 1.6633522643004786), ('spacelab', 1.6633522643004786)]
# ['The', 'Human', 'Genome', 'Project', ('thermodynamics', 2.1117496856150266), ('unhappiest', 2.0457827159518103), ('schedulers', 2.034495514585264)]
# ['Possible', 'Contributions', 'of', 'Gene', 'Mapping', 'to', 'Medicine', ('flexibly', 2.850345497541599), ('offfice', 2.744713527360491), ('calibration', 2.6556143174976468)]
# ['Diversification', 'by', 'Pacific', 'Telesis', ('interlinked', 1.7989053120370029), ('pacfic', 1.7691853598186853), ('woodworkers', 1.6767460951235202)]
# ['Expansion', 'in', 'the', 'U', 'S', 'Theme', 'Park', 'Industry', ('besuzzo', 3.7035694205520557), ('ncfc', 3.632814289308147), ('mutikori', 3.559054565998119)]
# ['Iranian', 'Support', 'for', 'Lebanese', 'Hostage', 'takers', ('etak', 2.3461096782087862), ('takings', 2.2877848714014934), ('thursay', 2.2364339219569693)]
# ['Irans', 'Islamic', 'Revolution', 'Domestic', 'and', 'Foreign', 'Social', 'Consequences', ('walstad', 2.8987852874093782), ('upturns', 2.7520135405862476), ('socialistic', 2.7075221482710004)]
# ['Political', 'Impact', 'of', 'Islamic', 'Fundamentalism', ('radicalism', 2.1862660232330615), ('politial', 2.1721250426247627), ('democractic', 2.1589335420957303)]
# ['Japans', 'Handling', 'of', 'its', 'Trade', 'Surplus', 'with', 'the', 'U', 'S', ('besuzzo', 4.199143404317859), ('unfpa', 4.169812153979197), ('ncfc', 4.079901221357074)]
# ['Impact', 'of', 'Government', 'Regulated', 'Grain', 'Farming', 'on', 'International', 'Relations', ('interntional', 3.638921411581714), ('offfice', 3.5470760042651697), ('governmment', 3.5302173029306494)]
# ['Why', 'Protect', 'U', 'S', 'Farmers', ('unfpa', 2.2471432492647017), ('besuzzo', 2.2098268382048847), ('discrepency', 2.154476553437772)]
# ['Management', 'Problems', 'at', 'the', 'United', 'Nations', ('ncfc', 2.830040990978082), ('prc', 2.758162822293402), ('mutikori', 2.694287521895796)]
# ['Influence', 'of', 'the', 'Pro', 'Israel', 'Lobby', ('mutikori', 2.740718319034758), ('ncfc', 2.717147047219803), ('minox', 2.534187834855654)]
# ['Negotiating', 'an', 'End', 'to', 'the', 'Nicaraguan', 'Civil', 'War', ('ncfc', 3.5451667867367838), ('mutikori', 3.468816302390504), ('minox', 3.370496298892107)]
# ['Productivity', 'Trends', 'in', 'the', 'U', 'S', 'Economy', ('besuzzo', 3.310988968385812), ('unfpa', 3.248538489182204), ('ncfc', 3.2312458460714995)]
# ['Conflict', 'in', 'the', 'Horn', 'of', 'Africa', ('mutikori', 2.81776505227379), ('mutikori', 2.81776505227379), ('ncfc', 2.704802139438795)]
# ['Industrial', 'Espionage', ('industralized', 0.8222554290096404), ('spying', 0.7579676532632555), ('agro', 0.7372708370776752)]
# ['U', 'S', 'Political', 'Campaign', 'Financing', ('unfpa', 2.2348769989181347), ('besuzzo', 2.172343522150352), ('campaing', 2.042834999972168)]
# ['Coping', 'with', 'overcrowded', 'prisons', ('witth', 1.6381334075277743), ('understaffed', 1.6082205808607357), ('unsanitary', 1.587726537468755)]
# ['Accusations', 'of', 'Cheating', 'by', 'Contractors', 'on', 'U', 'S', 'Defense', 'Projects', ('unfpa', 4.413038262263467), ('besuzzo', 4.332504959009826), ('interlinked', 4.253459704871337)]
# ['Insurance', 'Coverage', 'which', 'pays', 'for', 'Long', 'Term', 'Care', ('uncompensated', 3.589648992767851), ('etak', 3.4700944212515026), ('coverages', 3.4130924266370455)]
# ['Oil', 'Spills', ('spill', 1.182654089724974), ('oilfields', 1.0870003956548389), ('crude', 1.0264126256822115)]
# ['Right', 'Wing', 'Christian', 'Fundamentalism', 'in', 'U', 'S', ('mutikori', 3.093749240076606), ('besuzzo', 3.0458360925958905), ('bluffed', 2.9116429288128076)]
# ['Efforts', 'to', 'enact', 'Gun', 'Control', 'Legislation', ('flexibly', 2.607548323597327), ('enacts', 2.3798503138565414), ('cajole', 2.3566913573102326)]
# ['Causes', 'and', 'treatments', 'of', 'multiple', 'sclerosis', 'MS', ('myeloma', 3.155844277981905), ('rheumatoid', 3.1285129395196387), ('mesothelioma', 3.123053095761815)]
# ['Term', 'limitations', 'for', 'members', 'of', 'the', 'U', 'S', 'Congress', ('mutikori', 4.162782539472092), ('ncfc', 4.14965587094165), ('besuzzo', 4.148123461800167)]
# ['Electric', 'Car', 'Development', ('electic', 1.2716737623644965), ('electrification', 1.199966583963333), ('truck', 1.1230676075150434)]
# ['Vitamins', 'The', 'Cure', 'for', 'or', 'Cause', 'of', 'Human', 'Ailments', ('underdevelopment', 3.987765541437436), ('ncfc', 3.8845805844747847), ('unknowable', 3.848819385977577)]
# ['Acid', 'Rain', ('sulfuric', 1.0399047383434152), ('sleet', 1.0158032545158933), ('sulfur', 0.9941368268818095)]
# ['Automobile', 'Recalls', ('auto', 0.9395278959342248), ('car', 0.8335313389601858), ('coley', 0.798570130130189)]
# ['Vietnam', 'Veterans', 'and', 'Agent', 'Orange', ('ncoa', 2.0532299165394927), ('defoliant', 1.9958705482601002), ('amputees', 1.8504696033562218)]
# ['Generic', 'Drugs', 'Illegal', 'Activities', 'by', 'Manufacturers', ('loansharking', 2.49740795682618), ('interlinked', 2.4623992891516275), ('brandname', 2.4521941892329977)]
# ['Tobacco', 'company', 'advertising', 'and', 'the', 'young', ('ncfc', 2.841093969860781), ('minox', 2.779318168977471), ('mutikori', 2.683723478975415)]
# ['Standardized', 'testing', 'and', 'cultural', 'bias', ('walstad', 2.188119277876074), ('confirmatory', 2.169214272215663), ('politicization', 2.08089446642004)]
# ['Regulation', 'of', 'the', 'showing', 'of', 'violence', 'and', 'explicit', 'sex', 'in', 'motion', 'picture', 'theaters', 'on', 'television', 'and', 'on', 'video', 'cassettes', ('ncfc', 8.46031767617808), ('mutikori', 8.368628290509072), ('mutikori', 8.368628290509072)]
# ['Financing', 'AMTRAK', ('retrofitting', 0.8952505172826556), ('financings', 0.8880852782159212), ('coinsured', 0.8251307819730431)]
# ['Cost', 'of', 'Garbage', 'Trash', 'Removal', ('offfice', 2.044506186337514), ('rubbish', 1.8908821117560335), ('rubbish', 1.8908821117560335)]
# ['The', 'Consequences', 'of', 'Implantation', 'of', 'Silicone', 'Gel', 'Breast', 'Devices', ('secretes', 4.255288107229688), ('offfice', 4.217568979100987), ('offfice', 4.217568979100987)]
# ['Use', 'of', 'Mutual', 'Funds', 'in', 'an', 'Individuals', 'Retirement', 'Strategy', ('etak', 3.8611804584171967), ('wiesenberger', 3.722851949406713), ('mutikori', 3.721444048974697)]
# ['The', 'Effectiveness', 'of', 'Medical', 'Products', 'and', 'Related', 'Programs', 'Utilized', 'in', 'the', 'Cessation', 'of', 'Smoking', ('ncfc', 6.483972330861565), ('ncfc', 6.483972330861565), ('mutikori', 6.283262842589687)]
# ['Smoking', 'Bans', ('ban', 1.034156317254134), ('banning', 0.9541400650859494), ('nonsmoking', 0.8559098200096475)]
# ['Hazardous', 'Waste', 'Cleanup', ('wastes', 1.7388962529927383), ('decontamination', 1.6506449796375486), ('toxic', 1.5611667207689799)]
# ['NRA', 'Prevention', 'of', 'Gun', 'Control', 'Legislation', ('ofthe', 2.3028131860169507), ('perinatal', 2.2594703098219426), ('offfice', 2.2440717879236898)]
# ['Real', 'life', 'private', 'investigators', ('hirotomo', 1.6257912627007165), ('steppingstone', 1.5747285214690823), ('accrediting', 1.5005737765696023)]
# ['English', 'as', 'the', 'Official', 'Language', 'in', 'U', 'S', ('mutikori', 3.7045784713489787), ('mutikori', 3.7045784713489787), ('besuzzo', 3.6236558197129307)]
# ['Dog', 'Maulings', ('dogs', 0.6644454309401857), ('rottweiler', 0.5372001625933379), ('sled', 0.5358016134759418)]
# ['U', 'S', 'Restaurants', 'in', 'Foreign', 'Lands', ('unfpa', 2.6593531026712394), ('besuzzo', 2.648835173264756), ('mutikori', 2.6289561204933327)]
# ['Ineffectiveness', 'of', 'U', 'S', 'Embargoes', 'Sanctions', ('unfpa', 3.022391425886334), ('embargos', 2.9637989203520556), ('combativeness', 2.952146632938777)]
# ['Abuse', 'of', 'the', 'Elderly', 'by', 'Family', 'Members', 'and', 'Medical', 'and', 'Nonmedical', 'Personnel', 'and', 'Initiatives', 'Being', 'Taken', 'to', 'Minimize', 'This', 'Mistreatment', ('ncfc', 8.943904210335242), ('mutikori', 8.70795330863875), ('offfice', 8.261665933051416)]
# ['Commercial', 'Overfishing', 'Creates', 'Food', 'Fish', 'Deficit', ('gillnet', 2.6814920802639417), ('exportable', 2.672887166177989), ('woodburning', 2.646515911490427)]
# ['Asbestos', 'Related', 'Lawsuits', ('friable', 1.4077102075723364), ('countersuits', 1.3547441697978635), ('dioxins', 1.255692905840493)]
# ['Corporate', 'Pension', 'Plans', 'Funds', ('overfunded', 2.075705633542234), ('unfunded', 1.9018533414365628), ('infrequency', 1.703242292595419)]
# ['Reform', 'of', 'the', 'U', 'S', 'Welfare', 'System', ('unfpa', 3.2332464309679927), ('besuzzo', 3.193249177767404), ('ncfc', 3.1756163204996835)]
# ['Difference', 'of', 'Learning', 'Levels', 'Among', 'Inner', 'City', 'and', 'More', 'Suburban', 'School', 'Students', ('walstad', 4.991427141397392), ('offfice', 4.8226649874881975), ('commercializing', 4.66536896249223)]
# ['Signs', 'of', 'the', 'Demise', 'of', 'Independent', 'Publishing', ('ncfc', 3.102690452872906), ('mutikori', 3.018733137617951), ('allots', 2.912634174439743)]
# ['Beachfront', 'Erosion', ('oceanfront', 0.9741791796980411), ('landscaped', 0.9347448625088892), ('ritzy', 0.8434393114021348)]
# ['Real', 'Motives', 'for', 'Murder', ('etak', 1.6540932240254502), ('ulterior', 1.609030530220113), ('motivations', 1.5639162329984584)]
# ['Instances', 'of', 'Fraud', 'Involving', 'the', 'Use', 'of', 'a', 'Computer', ('ncfc', 4.030876971835145), ('allots', 3.991787572751732), ('mutikori', 3.9631243384803296)]
# ['Efforts', 'to', 'Improve', 'U', 'S', 'Schooling', ('unfpa', 2.81423828174185), ('besuzzo', 2.7995591435241574), ('flexibly', 2.7462598558686784)]
# ['Oil', 'Spill', 'Cleanup', ('spills', 1.659304017292366), ('exxon', 1.5769498967271756), ('fouled', 1.5603405757580342)]
# ['Toys', 'R', 'Dangerous', ('disorienting', 1.1564307140551675), ('hastert', 1.0335494784872767), ('wortley', 1.008958277933312)]
# ['The', 'Amount', 'of', 'Money', 'Earned', 'by', 'Writers', ('ncfc', 3.1133105914207913), ('allots', 3.0669019491770104), ('mutikori', 3.0616297716721297)]
# ['Stock', 'Market', 'Perturbations', 'Attributable', 'to', 'Computer', 'Initiated', 'Trading', ('flexibly', 2.9670496594009212), ('topix', 2.8729425749955766), ('shareholding', 2.871966634586965)]
# ['School', 'Choice', 'Voucher', 'System', 'and', 'its', 'effects', 'upon', 'the', 'entire', 'U', 'S', 'educational', 'program', ('ncfc', 6.350941768723997), ('unfpa', 6.241098118552363), ('besuzzo', 6.181141175267385)]
# ['Reform', 'of', 'the', 'jurisprudence', 'system', 'to', 'stop', 'juries', 'from', 'granting', 'unreasonable', 'monetary', 'awards', ('ncfc', 5.730527735620332), ('minox', 5.54475167916218), ('mutikori', 5.4950464753215975)]
# ['Gene', 'Therapy', 'and', 'Its', 'Benefits', 'to', 'Humankind', ('eventualy', 3.2297363581217136), ('flexibly', 3.139997402278436), ('walstad', 3.043439374799473)]
# ['Legality', 'of', 'Medically', 'Assisted', 'Suicides', ('offfice', 2.065037842197902), ('angiography', 2.007993298995636), ('ofthe', 1.971986909061708)]
# ['Impact', 'of', 'foreign', 'textile', 'imports', 'on', 'U', 'S', 'textile', 'industry', ('besuzzo', 4.441114665858748), ('unfpa', 4.225402817280347), ('annnounced', 3.930847552200902)]
